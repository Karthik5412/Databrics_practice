# %%
# %sql
select * from workspace.spark_practice.emp_data

# %%
# %sql
select concat(first_name, ' ',last_name) as Name from spark_practice.emp_data

# %%
# %sql
Select distinct department from workspace.spark_practice.emp_data

# %%
# %sql
SELECT * FROM workspace.spark_practice.emp_data WHERE salary > 50000

# %%
# %sql
SELECT * FROM workspace.spark_practice.emp_data WHERE salary < 50000

# %%
# %sql
SELECT * FROM workspace.spark_practice.emp_data WHERE AGE BETWEEN 25 AND 35

# %%
# %sql
SELECT * FROM workspace.spark_practice.emp_data WHERE department != 'HR'

# %%
# %sql
SELECT * FROM workspace.spark_practice.emp_data ORDER BY salary ASC

# %%
# %sql
SELECT * FROM workspace.spark_practice.emp_data ORDER BY salary DESC

# %%
# %sql
SELECT * FROM workspace.spark_practice.emp_data ORDER BY salary DESC LIMIT 5
