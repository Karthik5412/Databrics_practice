# %% [markdown]
# ### Data

# %%
bikes_schema = [
    'bike_id', 'bike_name', 'brand', 'engine_cc', 
    'mileage_kmpl', 'fuel_type', 'ex_showroom_price_inr', 'rto_tax_percent'
]

bikes_data = [
    (101, 'Splendor Plus', 'Hero', 97, 70, 'Petrol', 75000, 8),
    (102, 'Pulsar 150', 'Bajaj', 149, 45, 'Petrol', 115000, 10),
    (103, 'Shine 125', 'Honda', 124, 55, 'Petrol', 80000, 8),
    (104, 'Apache RTR 160', 'TVS', 160, 42, 'Petrol', 120000, 10),
    (105, 'Classic 350', 'Royal Enfield', 349, 35, 'Petrol', 193000, 12),
    (106, 'Activa 6G', 'Honda', 109, 50, 'Petrol', 78000, 8),
    (107, 'FZ S FI', 'Yamaha', 149, 45, 'Petrol', 116000, 10),
    (108, 'Platina 110', 'Bajaj', 115, 75, 'Petrol', 70000, 8),
    (109, 'Jupiter 125', 'TVS', 124, 50, 'Petrol', 86000, 8),
    (110, 'iQube', 'TVS', 0, 145, 'Electric', 140000, 4),
    (111, 'HF Deluxe', 'Hero', 97, 65, 'Petrol', 65000, 8),
    (112, 'Unicorn', 'Honda', 162, 50, 'Petrol', 110000, 10),
    (113, 'Glamour', 'Hero', 124, 55, 'Petrol', 82000, 8),
    (114, 'Access 125', 'Suzuki', 124, 48, 'Petrol', 85000, 8),
    (115, 'Pulsar NS200', 'Bajaj', 199, 35, 'Petrol', 148000, 12),
    (116, 'Dio 110', 'Honda', 109, 48, 'Petrol', 74000, 8),
    (117, 'Ntorq 125', 'TVS', 124, 40, 'Petrol', 95000, 8),
    (118, 'Bullet 350', 'Royal Enfield', 349, 35, 'Petrol', 174000, 12),
    (119, 'MT 15 V2', 'Yamaha', 155, 45, 'Petrol', 168000, 12),
    (120, 'Ola S1 Pro', 'Ola', 0, 195, 'Electric', 130000, 4)
]

# %%
bike = spark.createDataFrame(data= bikes_data, schema=bikes_schema)

bike.show()

# %%
customers_schema = [
    'customer_id', 'customer_name', 'city', 'state', 
    'age', 'gender', 'occupation', 'is_prime_member'
]

customers_data = [
    (1, 'Aarav Sharma', 'Delhi', 'Delhi', 28, 'M', 'Software Engineer', True),
    (2, 'Aditi Rao', 'Hyderabad', 'Telangana', 24, 'F', 'Student', False),
    (3, 'Arjun Nair', 'Kochi', 'Kerala', 31, 'M', 'Business Owner', True),
    (4, 'Ananya Patel', 'Ahmedabad', 'Gujarat', 22, 'F', 'Student', True),
    (5, 'Amit Mishra', 'Lucknow', 'Uttar Pradesh', 35, 'M', 'Govt Employee', False),
    (6, 'Anjali Gupta', 'Varanasi', 'Uttar Pradesh', 29, 'F', 'Teacher', False),
    (7, 'Akash Verma', 'Patna', 'Bihar', 26, 'M', 'Delivery Partner', True),
    (8, 'Amrita Das', 'Kolkata', 'West Bengal', 33, 'F', 'Banker', False),
    (9, 'Ajay Reddy', 'Hyderabad', 'Telangana', 40, 'M', 'Business Owner', True),
    (10, 'Aishwarya Sen', 'Kolkata', 'West Bengal', 27, 'F', 'Software Engineer', False),
    (11, 'Bhavana Reddy', 'Bengaluru', 'Karnataka', 25, 'F', 'Student', True),
    (12, 'Balaji Srinivasan', 'Chennai', 'Tamil Nadu', 45, 'M', 'Govt Employee', True),
    (13, 'Bhupendra Singh', 'Jaipur', 'Rajasthan', 38, 'M', 'Farmer', False),
    (14, 'Binita Jha', 'Ranchi', 'Jharkhand', 23, 'F', 'Student', False),
    (15, 'Chaitanya Kumar', 'Visakhapatnam', 'Andhra Pradesh', 30, 'M', 'Banker', True),
    (16, 'Chetan Joshi', 'Pune', 'Maharashtra', 32, 'M', 'Software Engineer', False),
    (17, 'Deepak Kumar', 'Patna', 'Bihar', 27, 'M', 'Teacher', False),
    (18, 'Divya Teja', 'Vijayawada', 'Andhra Pradesh', 24, 'F', 'Student', True),
    (19, 'Devendra Yadav', 'Kanpur', 'Uttar Pradesh', 42, 'M', 'Farmer', False),
    (20, 'Esha Choudhury', 'Guwahati', 'Assam', 26, 'F', 'Medical Professional', True),
    (21, 'Ganesh Hegde', 'Mangaluru', 'Karnataka', 34, 'M', 'Business Owner', False),
    (22, 'Gauri Kulkarni', 'Mumbai', 'Maharashtra', 29, 'F', 'Banker', True),
    (23, 'Gautam Gambhir', 'Delhi', 'Delhi', 41, 'M', 'Politician', True),
    (24, 'Hari Prasad', 'Vijayawada', 'Andhra Pradesh', 50, 'M', 'Retired', False),
    (25, 'Harini Murthy', 'Bengaluru', 'Karnataka', 23, 'F', 'Student', False),
    (26, 'Himanshu Sharma', 'Agra', 'Uttar Pradesh', 28, 'M', 'Software Engineer', True),
    (27, 'Ishaan Khattar', 'Mumbai', 'Maharashtra', 22, 'M', 'Student', False),
    (28, 'Indira Gandhi', 'Allahabad', 'Uttar Pradesh', 60, 'F', 'Retired', True),
    (29, 'Jagdish Prasad', 'Jaipur', 'Rajasthan', 47, 'M', 'Business Owner', False),
    (30, 'Jyoti Sharma', 'Jammu', 'Jammu & Kashmir', 31, 'F', 'Teacher', True),
    (31, 'Karthik Rao', 'Bengaluru', 'Karnataka', 24, 'M', 'Data Analyst', True),
    (32, 'Kavitha Krishnan', 'Chennai', 'Tamil Nadu', 36, 'F', 'Banker', False),
    (33, 'Kunal Kapoor', 'Chandigarh', 'Punjab', 29, 'M', 'Software Engineer', False),
    (34, 'Kiran Bedi', 'Amritsar', 'Punjab', 52, 'F', 'Retired', True),
    (35, 'Lokesh Rahul', 'Mangaluru', 'Karnataka', 31, 'M', 'Sports Coach', True),
    (36, 'Lalitha Kumari', 'Guntur', 'Andhra Pradesh', 43, 'F', 'Govt Employee', False),
    (37, 'Manish Pandey', 'Nainital', 'Uttarakhand', 33, 'M', 'Hotelier', False),
    (38, 'Meena Kumari', 'Patna', 'Bihar', 55, 'F', 'Retired', False),
    (39, 'Manoj Bajpayee', 'Bhopal', 'Madhya Pradesh', 48, 'M', 'Artist', True),
    (40, 'Nikhil Siddharth', 'Hyderabad', 'Telangana', 28, 'M', 'Software Engineer', True),
    (41, 'Nisha Agarwal', 'Mumbai', 'Maharashtra', 26, 'F', 'Student', False),
    (42, 'Nitin Gadkari', 'Nagpur', 'Maharashtra', 58, 'M', 'Govt Employee', True),
    (43, 'Naveen Patnaik', 'Bhubaneswar', 'Odisha', 62, 'M', 'Retired', False),
    (44, 'Om Prakash', 'Meerut', 'Uttar Pradesh', 45, 'M', 'Business Owner', False),
    (45, 'Pranav Mohan', 'Kochi', 'Kerala', 27, 'M', 'Software Engineer', True),
    (46, 'Priya Mani', 'Bengaluru', 'Karnataka', 34, 'F', 'Teacher', False),
    (47, 'Pankaj Tripathi', 'Gopalganj', 'Bihar', 44, 'M', 'Farmer', True),
    (48, 'Pradeep Kumar', 'Nellore', 'Andhra Pradesh', 39, 'M', 'Banker', False),
    (49, 'Pallavi Joshi', 'Pune', 'Maharashtra', 30, 'F', 'Software Engineer', True),
    (50, 'Rahul Dravid', 'Bengaluru', 'Karnataka', 49, 'M', 'Manager', True),
    (51, 'Ravi Teja', 'Hyderabad', 'Telangana', 35, 'M', 'Govt Employee', False),
    (52, 'Rupa Ganguly', 'Kolkata', 'West Bengal', 41, 'F', 'Teacher', True),
    (53, 'Rajesh Khanna', 'Amritsar', 'Punjab', 55, 'M', 'Retired', False),
    (54, 'Ram Charan', 'Hyderabad', 'Telangana', 33, 'M', 'Business Owner', True),
    (55, 'Sanjay Dutt', 'Mumbai', 'Maharashtra', 51, 'M', 'Business Owner', False),
    (56, 'Sai Pallavi', 'Coimbatore', 'Tamil Nadu', 28, 'F', 'Medical Professional', True),
    (57, 'Srinivas Murthy', 'Chennai', 'Tamil Nadu', 46, 'M', 'Banker', False),
    (58, 'Suresh Raina', 'Ghaziabad', 'Uttar Pradesh', 37, 'M', 'Delivery Partner', True),
    (59, 'Sneha Reddy', 'Hyderabad', 'Telangana', 25, 'F', 'Student', False),
    (60, 'Sandeep Kishan', 'Tirupati', 'Andhra Pradesh', 29, 'M', 'Software Engineer', False),
    (61, 'Tarun Kumar', 'Chennai', 'Tamil Nadu', 32, 'M', 'Software Engineer', True),
    (62, 'Tanmay Bhat', 'Mumbai', 'Maharashtra', 34, 'M', 'Content Creator', True),
    (63, 'Uday Kiran', 'Hyderabad', 'Telangana', 27, 'M', 'Student', False),
    (64, 'Uma Bharti', 'Jhansi', 'Uttar Pradesh', 53, 'F', 'Govt Employee', False),
    (65, 'Vijay Devarakonda', 'Hyderabad', 'Telangana', 31, 'M', 'Business Owner', True),
    (66, 'Venkatesh Daggubati', 'Warangal', 'Telangana', 54, 'M', 'Farmer', False),
    (67, 'Vineeth Sreenivasan', 'Kochi', 'Kerala', 36, 'M', 'Artist', True),
    (68, 'Varun Dhawan', 'Mumbai', 'Maharashtra', 29, 'M', 'Software Engineer', False),
    (69, 'Vikram Kennedy', 'Chennai', 'Tamil Nadu', 43, 'M', 'Manager', True),
    (70, 'Yash Gowda', 'Mysuru', 'Karnataka', 35, 'M', 'Business Owner', True),
    (71, 'Yuvraj Singh', 'Chandigarh', 'Punjab', 40, 'M', 'Sports Coach', False),
    (72, 'Zeenat Aman', 'Mumbai', 'Maharashtra', 59, 'F', 'Retired', False),
    (73, 'Abhinav Bindra', 'Dehradun', 'Uttarakhand', 38, 'M', 'Business Owner', True),
    (74, 'Alia Bhatt', 'Mumbai', 'Maharashtra', 25, 'F', 'Artist', True),
    (75, 'Anushka Shetty', 'Bengaluru', 'Karnataka', 36, 'F', 'Teacher', False),
    (76, 'Bhuvan Bam', 'Delhi', 'Delhi', 27, 'M', 'Content Creator', True),
    (77, 'Carry Minati', 'Faridabad', 'Haryana', 24, 'M', 'Content Creator', False),
    (78, 'Diljit Dosanjh', 'Jalandhar', 'Punjab', 35, 'M', 'Artist', True),
    (79, 'Hardik Pandya', 'Baroda', 'Gujarat', 28, 'M', 'Delivery Partner', False),
    (80, 'Ishant Sharma', 'Delhi', 'Delhi', 32, 'M', 'Govt Employee', False),
    (81, 'Jasprit Bumrah', 'Ahmedabad', 'Gujarat', 29, 'M', 'Software Engineer', True),
    (82, 'Kapil Dev', 'Chandigarh', 'Haryana', 61, 'M', 'Retired', True),
    (83, 'KL Rahul', 'Bengaluru', 'Karnataka', 30, 'M', 'Manager', False),
    (84, 'MS Dhoni', 'Ranchi', 'Jharkhand', 42, 'M', 'Govt Employee', True),
    (85, 'Mitthali Raj', 'Jodhpur', 'Rajasthan', 39, 'F', 'Sports Coach', False),
    (86, 'Narendra Modi', 'Mehsana', 'Gujarat', 65, 'M', 'Govt Employee', True),
    (87, 'Prithvi Shaw', 'Thane', 'Maharashtra', 23, 'M', 'Student', False),
    (88, 'Rishabh Pant', 'Roorkee', 'Uttarakhand', 25, 'M', 'Student', True),
    (89, 'Rohit Sharma', 'Nagpur', 'Maharashtra', 36, 'M', 'Manager', True),
    (90, 'Sanju Samson', 'Trivandrum', 'Kerala', 28, 'M', 'Software Engineer', False),
    (91, 'Shikhar Dhawan', 'Delhi', 'Delhi', 37, 'M', 'Business Owner', False),
    (92, 'Shreyas Iyer', 'Mumbai', 'Maharashtra', 28, 'M', 'Software Engineer', True),
    (93, 'Smriti Mandhana', 'Sangli', 'Maharashtra', 26, 'F', 'Banker', True),
    (94, 'Sunil Chhetri', 'Secunderabad', 'Telangana', 38, 'M', 'Govt Employee', True),
    (95, 'Sachin Tendulkar', 'Mumbai', 'Maharashtra', 48, 'M', 'Retired', True),
    (96, 'Virat Kohli', 'Delhi', 'Delhi', 34, 'M', 'Business Owner', True),
    (97, 'Sania Mirza', 'Hyderabad', 'Telangana', 36, 'F', 'Sports Coach', False),
    (98, 'Sunil Gavaskar', 'Mumbai', 'Maharashtra', 63, 'M', 'Retired', False),
    (99, 'Sourav Ganguly', 'Kolkata', 'West Bengal', 49, 'M', 'Manager', True),
    (100, 'Kapil Sharma', 'Amritsar', 'Punjab', 40, 'M', 'Artist', False),
    (101, 'Devansh Saxena', 'Lucknow', 'Uttar Pradesh', 29, 'M', 'Software Engineer', True),
    (102, 'Riya Sen', 'Kolkata', 'West Bengal', 23, 'F', 'Student', False),
    (103, 'Manvendra Pratap', 'Varanasi', 'Uttar Pradesh', 34, 'M', 'Govt Employee', True),
    (104, 'Ishita Dutta', 'Jamshedpur', 'Jharkhand', 27, 'F', 'Teacher', False),
    (105, 'Pranav Shah', 'Surat', 'Gujarat', 31, 'M', 'Business Owner', True),
    (106, 'Aniket Kulkarni', 'Nashik', 'Maharashtra', 26, 'M', 'Software Engineer', False),
    (107, 'Tanvi Rao', 'Mangaluru', 'Karnataka', 24, 'F', 'Banker', True),
    (108, 'Vikram Rathore', 'Udaipur', 'Rajasthan', 45, 'M', 'Business Owner', False),
    (109, 'Pooja Hegde', 'Udupi', 'Karnataka', 28, 'F', 'Artist', True),
    (110, 'Nitin Deshmukh', 'Aurangabad', 'Maharashtra', 39, 'M', 'Farmer', False),
    (111, 'Mehak Preet', 'Ludhiana', 'Punjab', 32, 'F', 'Medical Professional', True),
    (112, 'Harsh Vardhan', 'Meerut', 'Uttar Pradesh', 41, 'M', 'Govt Employee', False),
    (113, 'Deepika Padukone', 'Bengaluru', 'Karnataka', 38, 'F', 'Artist', True),
    (114, 'Ranbir Kapoor', 'Mumbai', 'Maharashtra', 41, 'M', 'Artist', False),
    (115, 'Siddharth Malhotra', 'Delhi', 'Delhi', 39, 'M', 'Manager', True),
    (116, 'Kiara Advani', 'Mumbai', 'Maharashtra', 32, 'F', 'Artist', True),
    (117, 'Varun Tej', 'Hyderabad', 'Telangana', 34, 'M', 'Business Owner', False),
    (118, 'Lavanya Tripathi', 'Dehradun', 'Uttarakhand', 33, 'F', 'Teacher', False),
    (119, 'Naga Chaitanya', 'Hyderabad', 'Telangana', 39, 'M', 'Business Owner', True),
    (120, 'Samantha Ruth', 'Chennai', 'Tamil Nadu', 37, 'F', 'Artist', True),
    (121, 'Allu Arjun', 'Palakollu', 'Andhra Pradesh', 42, 'M', 'Business Owner', True),
    (122, 'Rashmika Mandanna', 'Virajpet', 'Karnataka', 28, 'F', 'Student', True),
    (123, 'Prabhas Raju', 'Mogalthur', 'Andhra Pradesh', 44, 'M', 'Business Owner', False),
    (124, 'Kriti Sanon', 'Delhi', 'Delhi', 33, 'F', 'Software Engineer', False),
    (125, 'Tiger Shroff', 'Mumbai', 'Maharashtra', 34, 'M', 'Sports Coach', True),
    (126, 'Disha Patani', 'Bareilly', 'Uttar Pradesh', 32, 'F', 'Student', False),
    (127, 'Rajkummar Rao', 'Gurugram', 'Haryana', 39, 'M', 'Artist', True),
    (128, 'Patralekha Paul', 'Shillong', 'Meghalaya', 36, 'F', 'Teacher', False),
    (129, 'Ayushmann Khurrana', 'Chandigarh', 'Punjab', 41, 'M', 'Writer', True),
    (130, 'Tahira Kashyap', 'Chandigarh', 'Punjab', 41, 'F', 'Writer', False),
    (131, 'Vicky Kaushal', 'Mumbai', 'Maharashtra', 36, 'M', 'Software Engineer', True),
    (132, 'Katrina Kaif', 'London', 'UK', 40, 'F', 'Manager', True),
    (133, 'Ranveer Singh', 'Mumbai', 'Maharashtra', 38, 'M', 'Content Creator', False),
    (134, 'Arjun Kapoor', 'Mumbai', 'Maharashtra', 38, 'M', 'Business Owner', False),
    (135, 'Malaika Arora', 'Thane', 'Maharashtra', 48, 'F', 'Manager', True),
    (136, 'Janhavi Kapoor', 'Mumbai', 'Maharashtra', 27, 'F', 'Student', False),
    (137, 'Sara Ali Khan', 'Mumbai', 'Maharashtra', 28, 'F', 'Student', True),
    (138, 'Ananya Panday', 'Mumbai', 'Maharashtra', 25, 'F', 'Student', False),
    (139, 'Ishan Kishan', 'Patna', 'Bihar', 25, 'M', 'Delivery Partner', True),
    (140, 'Shubman Gill', 'Fazilka', 'Punjab', 24, 'M', 'Farmer', True),
    (141, 'Yuzvendra Chahal', 'Jind', 'Haryana', 33, 'M', 'Govt Employee', False),
    (142, 'Dhanashree Verma', 'Mumbai', 'Maharashtra', 30, 'F', 'Teacher', True),
    (143, 'Kuldeep Yadav', 'Kanpur', 'Uttar Pradesh', 29, 'M', 'Delivery Partner', False),
    (144, 'Axar Patel', 'Anand', 'Gujarat', 30, 'M', 'Govt Employee', True),
    (145, 'Ravindra Jadeja', 'Jamnagar', 'Gujarat', 37, 'M', 'Farmer', True),
    (146, 'Mohammed Shami', 'Amroha', 'Uttar Pradesh', 35, 'M', 'Business Owner', False),
    (147, 'Shreyas Gopal', 'Bengaluru', 'Karnataka', 30, 'M', 'Software Engineer', False),
    (148, 'Devdutt Padikkal', 'Edapal', 'Kerala', 23, 'M', 'Student', True),
    (149, 'Ruturaj Gaikwad', 'Pune', 'Maharashtra', 27, 'M', 'Manager', True),
    (150, 'Venkatesh Iyer', 'Indore', 'Madhya Pradesh', 29, 'M', 'Banker', False),
    (151, 'Nitish Rana', 'Delhi', 'Delhi', 30, 'M', 'Sports Coach', True),
    (152, 'Rahul Tewatia', 'Sihi', 'Haryana', 31, 'M', 'Govt Employee', False),
    (153, 'Deepak Chahar', 'Agra', 'Uttar Pradesh', 31, 'M', 'Delivery Partner', False),
    (154, 'Shardul Thakur', 'Palghar', 'Maharashtra', 32, 'M', 'Govt Employee', True),
    (155, 'Washington Sundar', 'Chennai', 'Tamil Nadu', 24, 'M', 'Student', True),
    (156, 'T Natarajan', 'Salem', 'Tamil Nadu', 33, 'M', 'Delivery Partner', False),
    (157, 'Prasidh Krishna', 'Bengaluru', 'Karnataka', 28, 'M', 'Software Engineer', True),
    (158, 'Avesh Khan', 'Indore', 'Madhya Pradesh', 27, 'M', 'Delivery Partner', False),
    (159, 'Arshdeep Singh', 'Guna', 'Madhya Pradesh', 25, 'M', 'Student', True),
    (160, 'Ravi Bishnoi', 'Jodhpur', 'Rajasthan', 23, 'M', 'Student', False),
    (161, 'Umran Malik', 'Jammu', 'Jammu & Kashmir', 24, 'M', 'Delivery Partner', True),
    (162, 'Shahrukh Khan', 'Chennai', 'Tamil Nadu', 28, 'M', 'Content Creator', False),
    (163, 'Abdul Samad', 'Kala Kot', 'Jammu & Kashmir', 24, 'M', 'Student', False),
    (164, 'Rinku Singh', 'Aligarh', 'Uttar Pradesh', 26, 'M', 'Delivery Partner', True),
    (165, 'Yashasvi Jaiswal', 'Bhadohi', 'Uttar Pradesh', 22, 'M', 'Student', True),
    (166, 'Tilak Varma', 'Hyderabad', 'Telangana', 23, 'M', 'Student', False),
    (167, 'Jitesh Sharma', 'Amravati', 'Maharashtra', 30, 'M', 'Banker', True),
    (168, 'Mukesh Kumar', 'Gopalganj', 'Bihar', 32, 'M', 'Govt Employee', False),
    (169, 'Sai Sudharsan', 'Chennai', 'Tamil Nadu', 24, 'M', 'Student', True),
    (170, 'Rajbawa', 'Nahan', 'Himachal Pradesh', 23, 'M', 'Student', False),
    (171, 'Yash Dhull', 'Delhi', 'Delhi', 23, 'M', 'Student', True),
    (172, 'Vicky Ostwal', 'Lonavala', 'Maharashtra', 23, 'M', 'Student', False),
    (173, 'Shaik Rasheed', 'Guntur', 'Andhra Pradesh', 22, 'M', 'Student', False),
    (174, 'Ravi Kumar', 'Alwar', 'Rajasthan', 23, 'M', 'Student', True),
    (175, 'Abhishek Sharma', 'Amritsar', 'Punjab', 25, 'M', 'Student', True),
    (176, 'Prabhsimran Singh', 'Patiala', 'Punjab', 25, 'M', 'Student', False),
    (177, 'Harpreet Brar', 'Moga', 'Punjab', 30, 'M', 'Farmer', True),
    (178, 'Anuj Rawat', 'Ramnagar', 'Uttarakhand', 24, 'M', 'Student', False),
    (179, 'Shahbaz Ahmed', 'Mewat', 'Haryana', 31, 'M', 'Banker', True),
    (180, 'Akash Deep', 'Sasaram', 'Bihar', 29, 'M', 'Govt Employee', False),
    (181, 'Suyash Sharma', 'Delhi', 'Delhi', 23, 'M', 'Student', True),
    (182, 'Vaibhav Arora', 'Ambala', 'Haryana', 28, 'M', 'Delivery Partner', False),
    (183, 'Vijaykumar Vyshak', 'Bengaluru', 'Karnataka', 29, 'M', 'Software Engineer', True),
    (184, 'Himanshu Sharma', 'Jaipur', 'Rajasthan', 28, 'M', 'Student', False),
    (185, 'Mayank Dagar', 'Delhi', 'Delhi', 29, 'M', 'Manager', True),
    (186, 'Mohit Sharma', 'Ballabhgarh', 'Haryana', 37, 'M', 'Retired', True),
    (187, 'Sai Kishore', 'Madurai', 'Tamil Nadu', 29, 'M', 'Teacher', False),
    (188, 'Abhinav Manohar', 'Bengaluru', 'Karnataka', 31, 'M', 'Business Owner', True),
    (189, 'Darshan Nalkande', 'Wardha', 'Maharashtra', 27, 'M', 'Farmer', False),
    (190, 'Jayant Yadav', 'Delhi', 'Delhi', 36, 'M', 'Govt Employee', True),
    (191, 'Pradeep Sangwan', 'Bhiwani', 'Haryana', 35, 'M', 'Retired', False),
    (192, 'Wriddhiman Saha', 'Shaktigarh', 'West Bengal', 41, 'M', 'Manager', True),
    (193, 'Srikar Bharat', 'Visakhapatnam', 'Andhra Pradesh', 32, 'M', 'Banker', False),
    (194, 'Kamlesh Nagarkoti', 'Barmer', 'Rajasthan', 26, 'M', 'Student', True),
    (195, 'Shivam Mavi', 'Noida', 'Uttar Pradesh', 27, 'M', 'Software Engineer', False),
    (196, 'Riyan Parag', 'Guwahati', 'Assam', 24, 'M', 'Student', True),
    (197, 'Dhruv Jurel', 'Agra', 'Uttar Pradesh', 25, 'M', 'Student', True),
    (198, 'Navdeep Saini', 'Karnal', 'Haryana', 33, 'M', 'Govt Employee', False),
    (199, 'Sandeep Sharma', 'Patiala', 'Punjab', 33, 'M', 'Delivery Partner', True),
    (200, 'Murugan Ashwin', 'Chennai', 'Tamil Nadu', 35, 'M', 'Teacher', False),
    (201, 'KC Cariappa', 'Bengaluru', 'Karnataka', 32, 'M', 'Sports Coach', False),
    (202, 'Pawan Negi', 'Delhi', 'Delhi', 33, 'M', 'Banker', True),
    (203, 'Shahbaz Nadeem', 'Muzaffarpur', 'Bihar', 36, 'M', 'Govt Employee', False),
    (204, 'Siddharth Kaul', 'Pathankot', 'Punjab', 36, 'M', 'Retired', True),
    (205, 'Karn Sharma', 'Jabalpur', 'Madhya Pradesh', 38, 'M', 'Govt Employee', False),
    (206, 'Mandeep Singh', 'Jalandhar', 'Punjab', 34, 'M', 'Manager', True),
    (207, 'Karun Nair', 'Jodhpur', 'Rajasthan', 34, 'M', 'Business Owner', True),
    (208, 'Stuart Binny', 'Bengaluru', 'Karnataka', 42, 'M', 'Retired', False),
    (209, 'Varun Aaron', 'Jamshedpur', 'Jharkhand', 36, 'M', 'Retired', True),
    (210, 'Parvez Rasool', 'Bijbehara', 'Jammu & Kashmir', 37, 'M', 'Farmer', False),
    (211, 'Manoj Tiwary', 'Howrah', 'West Bengal', 40, 'M', 'Politician', True),
    (212, 'Ashok Dinda', 'Chuchura', 'West Bengal', 42, 'M', 'Politician', False),
    (213, 'Suryakumar Yadav', 'Mumbai', 'Maharashtra', 35, 'M', 'Manager', True),
    (214, 'Ishana Nair', 'Palakkad', 'Kerala', 26, 'F', 'Student', False),
    (215, 'Meera Jasmine', 'Thiruvalla', 'Kerala', 32, 'F', 'Teacher', True),
    (216, 'Kavya Madhavan', 'Nileshwaram', 'Kerala', 35, 'F', 'Business Owner', False),
    (217, 'Manju Warrier', 'Nagercoil', 'Tamil Nadu', 44, 'F', 'Artist', True),
    (218, 'Nikhila Vimal', 'Taliparamba', 'Kerala', 28, 'F', 'Student', True),
    (219, 'Aishwarya Lekshmi', 'Trivandrum', 'Kerala', 31, 'F', 'Medical Professional', True),
    (220, 'Nimisha Sajayan', 'Mumbai', 'Maharashtra', 29, 'F', 'Artist', False),
    (221, 'Rajisha Vijayan', 'Perambra', 'Kerala', 30, 'F', 'Teacher', True),
    (222, 'Anupama Parameswaran', 'Irinjalakuda', 'Kerala', 28, 'F', 'Student', False),
    (223, 'Madonna Sebastian', 'Ernakulam', 'Kerala', 32, 'F', 'Artist', True),
    (224, 'Samyuktha Menon', 'Palakkad', 'Kerala', 30, 'F', 'Artist', True),
    (225, 'Malavika Mohanan', 'Payyanur', 'Kerala', 31, 'F', 'Content Creator', False),
    (226, 'Esther Anil', 'Wayand', 'Kerala', 24, 'F', 'Student', True),
    (227, 'Anikha Surendran', 'Manjeri', 'Kerala', 22, 'F', 'Student', False),
    (228, 'Nazriya Nazim', 'Trivandrum', 'Kerala', 31, 'F', 'Artist', True),
    (229, 'Parvathy Thiruvothu', 'Kozhikode', 'Kerala', 38, 'F', 'Artist', True),
    (230, 'Rima Kallingal', 'Thrissur', 'Kerala', 42, 'F', 'Artist', False),
    (231, 'Mamta Mohandas', 'Kannur', 'Kerala', 41, 'F', 'Medical Professional', True),
    (232, 'Priyamani Iyer', 'Palakkad', 'Kerala', 41, 'F', 'Teacher', False),
    (233, 'Amala Paul', 'Aluva', 'Kerala', 34, 'F', 'Artist', True),
    (234, 'Keerthy Suresh', 'Chennai', 'Tamil Nadu', 33, 'F', 'Artist', True),
    (235, 'Kalyani Priyadarshan', 'Chennai', 'Tamil Nadu', 31, 'F', 'Artist', True),
    (236, 'Nithya Menen', 'Bengaluru', 'Karnataka', 36, 'F', 'Artist', True),
    (237, 'Trisha Krishnan', 'Chennai', 'Tamil Nadu', 41, 'F', 'Artist', True),
    (238, 'Nayanthara Kurian', 'Thiruvalla', 'Kerala', 41, 'F', 'Business Owner', True),
    (239, 'Tamannaah Bhatia', 'Mumbai', 'Maharashtra', 36, 'F', 'Artist', False),
    (240, 'Kajal Aggarwal', 'Mumbai', 'Maharashtra', 39, 'F', 'Artist', True),
    (241, 'Shruti Haasan', 'Chennai', 'Tamil Nadu', 38, 'F', 'Artist', False),
    (242, 'Taapsee Pannu', 'New Delhi', 'Delhi', 36, 'F', 'Artist', True),
    (243, 'Rakul Preet', 'New Delhi', 'Delhi', 35, 'F', 'Artist', True),
    (244, 'Ileana D\'Cruz', 'Mumbai', 'Maharashtra', 39, 'F', 'Artist', False),
    (245, 'Samantha Akkineni', 'Chennai', 'Tamil Nadu', 37, 'F', 'Artist', True),
    (246, 'Pooja Ramachandran', 'Chennai', 'Tamil Nadu', 39, 'F', 'Content Creator', False),
    (247, 'Regina Cassandra', 'Chennai', 'Tamil Nadu', 35, 'F', 'Artist', True),
    (248, 'Niveda Thomas', 'Chennai', 'Tamil Nadu', 28, 'F', 'Student', True),
    (249, 'Shalini Pandey', 'Jabalpur', 'Madhya Pradesh', 30, 'F', 'Student', False),
    (250, 'Eesha Rebba', 'Hyderabad', 'Telangana', 33, 'F', 'Software Engineer', True),
    (251, 'Ananya Nagalla', 'Suryapet', 'Telangana', 29, 'F', 'Software Engineer', False),
    (252, 'Chandini Chowdary', 'Vizag', 'Andhra Pradesh', 31, 'F', 'Artist', True),
    (253, 'Nandita Swetha', 'Bengaluru', 'Karnataka', 34, 'F', 'Teacher', False),
    (254, 'Hebah Patel', 'Mumbai', 'Maharashtra', 31, 'F', 'Student', True),
    (255, 'Tejaswi Madivada', 'Hyderabad', 'Telangana', 33, 'F', 'Content Creator', False),
    (256, 'Sri Divya', 'Hyderabad', 'Telangana', 31, 'F', 'Teacher', True),
    (257, 'Swathi Reddy', 'Vladivostok', 'Russia', 39, 'F', 'Manager', True),
    (258, 'Pranitha Subhash', 'Bengaluru', 'Karnataka', 31, 'F', 'Business Owner', True),
    (259, 'Hariprriya', 'Chikkaballapur', 'Karnataka', 34, 'F', 'Artist', False),
    (260, 'Radhika Pandit', 'Uttara Kannada', 'Karnataka', 40, 'F', 'Manager', True),
    (261, 'Rachita Ram', 'Bengaluru', 'Karnataka', 31, 'F', 'Artist', False),
    (262, 'Ashika Ranganath', 'Tumkur', 'Karnataka', 27, 'F', 'Student', True),
    (263, 'Sreeleela', 'Detroit', 'USA', 24, 'F', 'Medical Professional', True),
    (264, 'Krithi Shetty', 'Mangaluru', 'Karnataka', 22, 'F', 'Student', False),
    (265, 'Meenakshi Chaudhary', 'Panchkula', 'Haryana', 27, 'F', 'Medical Professional', True),
    (266, 'Dimple Hayathi', 'Hyderabad', 'Telangana', 25, 'F', 'Student', False),
    (267, 'Nabha Natesh', 'Sringeri', 'Karnataka', 28, 'F', 'Student', True),
    (268, 'Nidhhi Agerwal', 'Hyderabad', 'Telangana', 30, 'F', 'Content Creator', True),
    (269, 'Payal Rajput', 'Delhi', 'Delhi', 33, 'F', 'Artist', False),
    (270, 'Raashi Khanna', 'Delhi', 'Delhi', 33, 'F', 'Artist', True),
    (271, 'Nidhi Hegde', 'Sirsi', 'Karnataka', 25, 'F', 'Software Engineer', True),
    (272, 'Divya Spandana', 'Bengaluru', 'Karnataka', 41, 'F', 'Politician', False),
    (273, 'Aindrita Ray', 'Udaipur', 'Rajasthan', 39, 'F', 'Artist', True),
    (274, 'Meghana Raj', 'Bengaluru', 'Karnataka', 34, 'F', 'Manager', False),
    (275, 'Shruti Hariharan', 'Trivandrum', 'Kerala', 35, 'F', 'Teacher', True),
    (276, 'Samyukta Hornad', 'Bengaluru', 'Karnataka', 33, 'F', 'Content Creator', True),
    (277, 'Deepa Sannidhi', 'Chikkamagaluru', 'Karnataka', 34, 'F', 'Teacher', False),
    (278, 'Manvitha Kamath', 'Mangaluru', 'Karnataka', 32, 'F', 'Artist', True),
    (279, 'Karunya Ram', 'Bengaluru', 'Karnataka', 31, 'F', 'Student', False),
    (280, 'Mayuri Kyatari', 'Hubli', 'Karnataka', 33, 'F', 'Teacher', True),
    (281, 'Aditi Prabhudeva', 'Davangere', 'Karnataka', 30, 'F', 'Content Creator', True),
    (282, 'Amrutha Iyengar', 'Mysuru', 'Karnataka', 26, 'F', 'Student', False),
    (283, 'Nisvika Naidu', 'Bengaluru', 'Karnataka', 28, 'F', 'Student', True),
    (284, 'Kavya Shetty', 'Mangaluru', 'Karnataka', 34, 'F', 'Manager', True),
    (285, 'Shubha Poonja', 'Mangaluru', 'Karnataka', 41, 'F', 'Artist', False),
    (286, 'Sanjjanaa Galrani', 'Bengaluru', 'Karnataka', 40, 'F', 'Business Owner', True),
    (287, 'Ragini Dwivedi', 'Bengaluru', 'Karnataka', 34, 'F', 'Artist', False),
    (288, 'Nikita Thukral', 'Mumbai', 'Maharashtra', 41, 'F', 'Manager', True),
    (289, 'Srinidhi Shetty', 'Mangaluru', 'Karnataka', 31, 'F', 'Software Engineer', True),
    (290, 'Ruhani Sharma', 'Solan', 'Himachal Pradesh', 31, 'F', 'Student', False),
    (291, 'Priyanka Arul', 'Chennai', 'Tamil Nadu', 30, 'F', 'Software Engineer', True),
    (292, 'Dushara Vijayan', 'Dindigul', 'Tamil Nadu', 28, 'F', 'Student', False),
    (293, 'Aparna Balamurali', 'Thrissur', 'Kerala', 30, 'F', 'Artist', True),
    (294, 'Lijomol Jose', 'Idukki', 'Kerala', 33, 'F', 'Teacher', True),
    (295, 'Reba Monica', 'Bengaluru', 'Karnataka', 32, 'F', 'Banker', False),
    (296, 'Mirnalini Ravi', 'Pondicherry', 'Puducherry', 28, 'F', 'Software Engineer', True),
    (297, 'Iswarya Menon', 'Erode', 'Tamil Nadu', 31, 'F', 'Student', False),
    (298, 'Athulya Ravi', 'Coimbatore', 'Tamil Nadu', 30, 'F', 'Student', True),
    (299, 'Indhuja Ravichandran', 'Vellore', 'Tamil Nadu', 32, 'F', 'Software Engineer', False),
    (300, 'Amritha Aiyer', 'Chennai', 'Tamil Nadu', 30, 'F', 'Student', True),
    (301, 'Anagha Maruthora', 'Kozhikode', 'Kerala', 28, 'F', 'Student', True),
    (302, 'Sshivada', 'Trichy', 'Tamil Nadu', 35, 'F', 'Manager', False),
    (303, 'Ramya Nambeesan', 'Chottanikkara', 'Kerala', 40, 'F', 'Artist', True),
    (304, 'Janani Iyer', 'Chennai', 'Tamil Nadu', 35, 'F', 'Manager', False),
    (305, 'Anjali Deva', 'Razole', 'Andhra Pradesh', 39, 'F', 'Artist', True),
    (306, 'Dhansika', 'Thanjavur', 'Tamil Nadu', 36, 'F', 'Sports Coach', True),
    (307, 'Sunainaa', 'Nagpur', 'Maharashtra', 37, 'F', 'Artist', False),
    (308, 'Bindu Madhavi', 'Madanapalle', 'Andhra Pradesh', 39, 'F', 'Artist', True),
    (309, 'Oviya Helen', 'Thrissur', 'Kerala', 35, 'F', 'Content Creator', False),
    (310, 'Raiza Wilson', 'Bengaluru', 'Karnataka', 36, 'F', 'Content Creator', True),
    (311, 'Yashika Aannand', 'New Delhi', 'Delhi', 26, 'F', 'Student', True),
    (312, 'Aishwarya Rajesh', 'Chennai', 'Tamil Nadu', 36, 'F', 'Artist', True),
    (313, 'Lakshmi Menon', 'Kochi', 'Kerala', 30, 'F', 'Student', False),
    (314, 'Mahima Nambiar', 'Kasaragod', 'Kerala', 30, 'F', 'Student', True),
    (315, 'Arthana Binu', 'Trivandrum', 'Kerala', 28, 'F', 'Student', False),
    (316, 'Gouri Kishan', 'Kochi', 'Kerala', 26, 'F', 'Student', True),
    (317, 'Aditi Balan', 'Chennai', 'Tamil Nadu', 32, 'F', 'Banker', True),
    (318, 'Sai Dhanshika', 'Thanjavur', 'Tamil Nadu', 36, 'F', 'Sports Coach', False),
    (319, 'Andrea Jeremiah', 'Chennai', 'Tamil Nadu', 40, 'F', 'Artist', True),
    (320, 'Varalaxmi Sarathkumar', 'Bengaluru', 'Karnataka', 41, 'F', 'Artist', True),
    (321, 'Rai Laxmi', 'Belagavi', 'Karnataka', 37, 'F', 'Artist', False),
    (322, 'Poorna', 'Kannur', 'Kerala', 37, 'F', 'Teacher', True),
    (323, 'Madhoo Shah', 'Chennai', 'Tamil Nadu', 54, 'F', 'Retired', True),
    (324, 'Simran Bagga', 'Mumbai', 'Maharashtra', 50, 'F', 'Retired', True),
    (325, 'Jyothika Sadanah', 'Mumbai', 'Maharashtra', 47, 'F', 'Business Owner', True),
    (326, 'Meena Durairaj', 'Chennai', 'Tamil Nadu', 49, 'F', 'Manager', False),
    (327, 'Rojamani', 'Tirupati', 'Andhra Pradesh', 53, 'F', 'Politician', True),
    (328, 'Ramya Krishnan', 'Chennai', 'Tamil Nadu', 55, 'F', 'Artist', True),
    (329, 'Khushbu Sundar', 'Mumbai', 'Maharashtra', 55, 'F', 'Politician', True),
    (330, 'Radhika Sarathkumar', 'Colombo', 'Sri Lanka', 63, 'F', 'Business Owner', False),
    (331, 'Suhasini Maniratnam', 'Paramakudi', 'Tamil Nadu', 64, 'F', 'Manager', True),
    (332, 'Shobana Chandrakumar', 'Trivandrum', 'Kerala', 56, 'F', 'Teacher', True),
    (333, 'Revathi Asha', 'Kochi', 'Kerala', 59, 'F', 'Manager', False),
    (334, 'Urvashi Kavitha', 'Trivandrum', 'Kerala', 56, 'F', 'Artist', True),
    (335, 'Nadia Moidu', 'Mumbai', 'Maharashtra', 59, 'F', 'Manager', True),
    (336, 'Ambika', 'Kallara', 'Kerala', 63, 'F', 'Retired', False),
    (337, 'Radha', 'Kallara', 'Kerala', 61, 'F', 'Farmer', True),
    (338, 'Gautami Tadimalla', 'Srikakulam', 'Andhra Pradesh', 57, 'F', 'Politician', True),
    (339, 'Amala Akkineni', 'Kolkata', 'West Bengal', 58, 'F', 'Govt Employee', True),
    (340, 'Vijayashanti', 'Hyderabad', 'Telangana', 60, 'F', 'Politician', False),
    (341, 'Jayasudha', 'Chennai', 'Tamil Nadu', 67, 'F', 'Politician', True),
    (342, 'Jayaprada', 'Rajahmundry', 'Andhra Pradesh', 64, 'F', 'Politician', False),
    (343, 'Sridevi Kapoor', 'Sivakasi', 'Tamil Nadu', 54, 'F', 'Retired', True),
    (344, 'Madhuri Dixit', 'Mumbai', 'Maharashtra', 59, 'F', 'Artist', True),
    (345, 'Juhi Chawla', 'Ambala', 'Haryana', 58, 'F', 'Business Owner', False),
    (346, 'Karisma Kapoor', 'Mumbai', 'Maharashtra', 52, 'F', 'Manager', True),
    (347, 'Kareena Kapoor', 'Mumbai', 'Maharashtra', 45, 'F', 'Artist', True),
    (348, 'Rani Mukerji', 'Mumbai', 'Maharashtra', 48, 'F', 'Manager', True),
    (349, 'Preity Zinta', 'Shimla', 'Himachal Pradesh', 51, 'F', 'Business Owner', False),
    (350, 'Aishwarya Rai', 'Mangaluru', 'Karnataka', 52, 'F', 'Artist', True),
    (351, 'Sushmita Sen', 'Hyderabad', 'Telangana', 50, 'F', 'Manager', True),
    (352, 'Lara Dutta', 'Ghaziabad', 'Uttar Pradesh', 48, 'F', 'Manager', False),
    (353, 'Priyanka Chopra', 'Jamshedpur', 'Jharkhand', 43, 'F', 'Business Owner', True),
    (354, 'Dia Mirza', 'Hyderabad', 'Telangana', 44, 'F', 'Manager', False),
    (355, 'Neha Dhupia', 'Kochi', 'Kerala', 45, 'F', 'Content Creator', True),
    (356, 'Sooha Ali Khan', 'New Delhi', 'Delhi', 47, 'F', 'Writer', True),
    (357, 'Konkona Sen', 'Kolkata', 'West Bengal', 46, 'F', 'Writer', False),
    (358, 'Vidya Balan', 'Mumbai', 'Maharashtra', 47, 'F', 'Artist', True),
    (359, 'Bipasha Basu', 'New Delhi', 'Delhi', 47, 'F', 'Manager', False),
    (360, 'Chitrangada Singh', 'Jodhpur', 'Rajasthan', 49, 'F', 'Content Creator', True),
    (361, 'Huma Qureshi', 'New Delhi', 'Delhi', 39, 'F', 'Artist', True),
    (362, 'Radhika Apte', 'Vellore', 'Tamil Nadu', 40, 'F', 'Artist', False),
    (363, 'Kalki Koechlin', 'Pondicherry', 'Puducherry', 42, 'F', 'Artist', True),
    (364, 'Swara Bhasker', 'Delhi', 'Delhi', 38, 'F', 'Content Creator', True),
    (365, 'Richa Chadha', 'Amritsar', 'Punjab', 39, 'F', 'Artist', False),
    (366, 'Nimrat Kaur', 'Pilani', 'Rajasthan', 44, 'F', 'Manager', True),
    (367, 'Yami Gautam', 'Bilaspur', 'Himachal Pradesh', 37, 'F', 'Artist', True),
    (368, 'Taapsee Pannu', 'New Delhi', 'Delhi', 38, 'F', 'Artist', False),
    (369, 'Bhumi Pednekar', 'Mumbai', 'Maharashtra', 36, 'F', 'Manager', True),
    (370, 'Kiara Advani', 'Mumbai', 'Maharashtra', 33, 'F', 'Artist', True),
    (371, 'Kriti Sanon', 'New Delhi', 'Delhi', 35, 'F', 'Software Engineer', False),
    (372, 'Shraddha Kapoor', 'Mumbai', 'Maharashtra', 39, 'F', 'Artist', True),
    (373, 'Sonam Kapoor', 'Mumbai', 'Maharashtra', 41, 'F', 'Business Owner', False),
    (374, 'Sonakshi Sinha', 'Mumbai', 'Maharashtra', 39, 'F', 'Artist', True),
    (375, 'Parineeti Chopra', 'Ambala', 'Haryana', 37, 'F', 'Manager', True),
    (376, 'Ileana D\'Cruz', 'Mumbai', 'Maharashtra', 39, 'F', 'Artist', False),
    (377, 'Esha Gupta', 'New Delhi', 'Delhi', 40, 'F', 'Student', True),
    (378, 'Nargis Fakhri', 'Queens', 'USA', 46, 'F', 'Content Creator', False),
    (379, 'Jacqueline Fernandez', 'Manama', 'Bahrain', 40, 'F', 'Artist', True),
    (380, 'Asin Thottumkal', 'Kochi', 'Kerala', 40, 'F', 'Retired', True),
    (381, 'Genelia D\'Souza', 'Mumbai', 'Maharashtra', 38, 'F', 'Manager', False),
    (382, 'Ayesha Takia', 'Mumbai', 'Maharashtra', 40, 'F', 'Retired', True),
    (383, 'Amrita Rao', 'Mumbai', 'Maharashtra', 45, 'F', 'Manager', True),
    (384, 'Bhumika Chawla', 'New Delhi', 'Delhi', 47, 'F', 'Teacher', False),
    (385, 'Dia Mirza', 'Hyderabad', 'Telangana', 44, 'F', 'Manager', True),
    (386, 'Raveena Tandon', 'Mumbai', 'Maharashtra', 51, 'F', 'Manager', True),
    (387, 'Urmila Matondkar', 'Mumbai', 'Maharashtra', 52, 'F', 'Politician', False),
    (388, 'Twinkle Khanna', 'Pune', 'Maharashtra', 52, 'F', 'Writer', True),
    (389, 'Shilpa Shetty', 'Mangaluru', 'Karnataka', 51, 'F', 'Business Owner', True),
    (390, 'Sushmita Sen', 'Hyderabad', 'Telangana', 50, 'F', 'Manager', False),
    (391, 'Aishwarya Rai', 'Mangaluru', 'Karnataka', 52, 'F', 'Artist', True),
    (392, 'Tabu Hashmi', 'Hyderabad', 'Telangana', 54, 'F', 'Artist', True),
    (393, 'Kajol Devgan', 'Mumbai', 'Maharashtra', 51, 'F', 'Artist', True),
    (394, 'Karishma Kapoor', 'Mumbai', 'Maharashtra', 52, 'F', 'Manager', False),
    (395, 'Raveena Tandon', 'Mumbai', 'Maharashtra', 51, 'F', 'Manager', True),
    (396, 'Manisha Koirala', 'Kathmandu', 'Nepal', 55, 'F', 'Social Worker', True),
    (397, 'Pooja Bhatt', 'Mumbai', 'Maharashtra', 54, 'F', 'Writer', False),
    (398, 'Divya Bharti', 'Mumbai', 'Maharashtra', 52, 'F', 'Retired', True),
    (399, 'Juhi Chawla', 'Ambala', 'Haryana', 58, 'F', 'Business Owner', True),
    (400, 'Madhuri Dixit', 'Mumbai', 'Maharashtra', 59, 'F', 'Artist', False),
    (401, 'Sridevi Kapoor', 'Sivakasi', 'Tamil Nadu', 54, 'F', 'Retired', True),
    (402, 'Jayaprada', 'Rajahmundry', 'Andhra Pradesh', 64, 'F', 'Politician', True),
    (403, 'Jayasudha', 'Chennai', 'Tamil Nadu', 67, 'F', 'Politician', False),
    (404, 'Vijayashanti', 'Hyderabad', 'Telangana', 60, 'F', 'Politician', True),
    (405, 'Amala Akkineni', 'Kolkata', 'West Bengal', 58, 'F', 'Govt Employee', False),
    (406, 'Gautami Tadimalla', 'Srikakulam', 'Andhra Pradesh', 57, 'F', 'Politician', True),
    (407, 'Radha Kallara', 'Kallara', 'Kerala', 61, 'F', 'Farmer', True),
    (408, 'Ambika Kallara', 'Kallara', 'Kerala', 63, 'F', 'Retired', False),
    (409, 'Nadia Moidu', 'Mumbai', 'Maharashtra', 59, 'F', 'Manager', True),
    (410, 'Urvashi Kavitha', 'Trivandrum', 'Kerala', 56, 'F', 'Artist', False),
    (411, 'Revathi Asha', 'Kochi', 'Kerala', 59, 'F', 'Manager', True),
    (412, 'Shobana Chandrakumar', 'Trivandrum', 'Kerala', 56, 'F', 'Teacher', True),
    (413, 'Suhasini Maniratnam', 'Paramakudi', 'Tamil Nadu', 64, 'F', 'Manager', False),
    (414, 'Radhika Sarathkumar', 'Colombo', 'Sri Lanka', 63, 'F', 'Business Owner', True),
    (415, 'Khushbu Sundar', 'Mumbai', 'Maharashtra', 55, 'F', 'Politician', True),
    (416, 'Ramya Krishnan', 'Chennai', 'Tamil Nadu', 55, 'F', 'Artist', False),
    (417, 'Rojamani', 'Tirupati', 'Andhra Pradesh', 53, 'F', 'Politician', True),
    (418, 'Meena Durairaj', 'Chennai', 'Tamil Nadu', 49, 'F', 'Manager', True),
    (419, 'Jyothika Sadanah', 'Mumbai', 'Maharashtra', 47, 'F', 'Business Owner', False),
    (420, 'Simran Bagga', 'Mumbai', 'Maharashtra', 50, 'F', 'Retired', True),
    (421, 'Madhoo Shah', 'Chennai', 'Tamil Nadu', 54, 'F', 'Retired', True),
    (422, 'Poorna Kannur', 'Kannur', 'Kerala', 37, 'F', 'Teacher', False),
    (423, 'Rai Laxmi', 'Belagavi', 'Karnataka', 37, 'F', 'Artist', True),
    (424, 'Varalaxmi Sarathkumar', 'Bengaluru', 'Karnataka', 41, 'F', 'Artist', True),
    (425, 'Andrea Jeremiah', 'Chennai', 'Tamil Nadu', 40, 'F', 'Artist', False),
    (426, 'Sai Dhanshika', 'Thanjavur', 'Tamil Nadu', 36, 'F', 'Sports Coach', True),
    (427, 'Aditi Balan', 'Chennai', 'Tamil Nadu', 32, 'F', 'Banker', True),
    (428, 'Gouri Kishan', 'Kochi', 'Kerala', 26, 'F', 'Student', False),
    (429, 'Arthana Binu', 'Trivandrum', 'Kerala', 28, 'F', 'Student', True),
    (430, 'Mahima Nambiar', 'Kasaragod', 'Kerala', 30, 'F', 'Student', False),
    (431, 'Lakshmi Menon', 'Kochi', 'Kerala', 30, 'F', 'Student', True),
    (432, 'Aishwarya Rajesh', 'Chennai', 'Tamil Nadu', 36, 'F', 'Artist', True),
    (433, 'Yashika Aannand', 'New Delhi', 'Delhi', 26, 'F', 'Student', False),
    (434, 'Raiza Wilson', 'Bengaluru', 'Karnataka', 36, 'F', 'Content Creator', True),
    (435, 'Oviya Helen', 'Thrissur', 'Kerala', 35, 'F', 'Content Creator', True),
    (436, 'Bindu Madhavi', 'Madanapalle', 'Andhra Pradesh', 39, 'F', 'Artist', False),
    (437, 'Sunainaa Nagpur', 'Nagpur', 'Maharashtra', 37, 'F', 'Artist', True),
    (438, 'Dhansika Thanjavur', 'Thanjavur', 'Tamil Nadu', 36, 'F', 'Sports Coach', True),
    (439, 'Anjali Deva', 'Razole', 'Andhra Pradesh', 39, 'F', 'Artist', False),
    (440, 'Janani Iyer', 'Chennai', 'Tamil Nadu', 35, 'F', 'Manager', True),
    (441, 'Ramya Nambeesan', 'Chottanikkara', 'Kerala', 40, 'F', 'Artist', True),
    (442, 'Sshivada Trichy', 'Trichy', 'Tamil Nadu', 35, 'F', 'Manager', False),
    (443, 'Anagha Maruthora', 'Kozhikode', 'Kerala', 28, 'F', 'Student', True),
    (444, 'Amritha Aiyer', 'Chennai', 'Tamil Nadu', 30, 'F', 'Student', False),
    (445, 'Indhuja Ravichandran', 'Vellore', 'Tamil Nadu', 32, 'F', 'Software Engineer', True),
    (446, 'Athulya Ravi', 'Coimbatore', 'Tamil Nadu', 30, 'F', 'Student', True),
    (447, 'Iswarya Menon', 'Erode', 'Tamil Nadu', 31, 'F', 'Student', False),
    (448, 'Mirnalini Ravi', 'Pondicherry', 'Puducherry', 28, 'F', 'Software Engineer', True),
    (449, 'Reba Monica', 'Bengaluru', 'Karnataka', 32, 'F', 'Banker', True),
    (450, 'Lijomol Jose', 'Idukki', 'Kerala', 33, 'F', 'Teacher', False),
    (451, 'Aparna Balamurali', 'Thrissur', 'Kerala', 30, 'F', 'Artist', True),
    (452, 'Dushara Vijayan', 'Dindigul', 'Tamil Nadu', 28, 'F', 'Student', False),
    (453, 'Priyanka Arul', 'Chennai', 'Tamil Nadu', 30, 'F', 'Software Engineer', True),
    (454, 'Ruhani Sharma', 'Solan', 'Himachal Pradesh', 31, 'F', 'Student', True),
    (455, 'Srinidhi Shetty', 'Mangaluru', 'Karnataka', 31, 'F', 'Software Engineer', False),
    (456, 'Nikita Thukral', 'Mumbai', 'Maharashtra', 41, 'F', 'Manager', True),
    (457, 'Ragini Dwivedi', 'Bengaluru', 'Karnataka', 34, 'F', 'Artist', True),
    (458, 'Sanjjanaa Galrani', 'Bengaluru', 'Karnataka', 40, 'F', 'Business Owner', False),
    (459, 'Shubha Poonja', 'Mangaluru', 'Karnataka', 41, 'F', 'Artist', True),
    (460, 'Kavya Shetty', 'Mangaluru', 'Karnataka', 34, 'F', 'Manager', False),
    (461, 'Nisvika Naidu', 'Bengaluru', 'Karnataka', 28, 'F', 'Student', True),
    (462, 'Amrutha Iyengar', 'Mysuru', 'Karnataka', 26, 'F', 'Student', True),
    (463, 'Aditi Prabhudeva', 'Davangere', 'Karnataka', 30, 'F', 'Content Creator', False),
    (464, 'Mayuri Kyatari', 'Hubli', 'Karnataka', 33, 'F', 'Teacher', True),
    (465, 'Karunya Ram', 'Bengaluru', 'Karnataka', 31, 'F', 'Student', True),
    (466, 'Manvitha Kamath', 'Mangaluru', 'Karnataka', 32, 'F', 'Artist', False),
    (467, 'Deepa Sannidhi', 'Chikkamagaluru', 'Karnataka', 34, 'F', 'Teacher', True),
    (468, 'Samyukta Hornad', 'Bengaluru', 'Karnataka', 33, 'F', 'Content Creator', False),
    (469, 'Shruti Hariharan', 'Trivandrum', 'Kerala', 35, 'F', 'Teacher', True),
    (470, 'Meghana Raj', 'Bengaluru', 'Karnataka', 34, 'F', 'Manager', True),
    (471, 'Aindrita Ray', 'Udaipur', 'Rajasthan', 39, 'F', 'Artist', False),
    (472, 'Divya Spandana', 'Bengaluru', 'Karnataka', 41, 'F', 'Politician', True),
    (473, 'Nidhi Hegde', 'Sirsi', 'Karnataka', 25, 'F', 'Software Engineer', True),
    (474, 'Raashi Khanna', 'Delhi', 'Delhi', 33, 'F', 'Artist', False),
    (475, 'Payal Rajput', 'Delhi', 'Delhi', 33, 'F', 'Artist', True),
    (476, 'Nidhhi Agerwal', 'Hyderabad', 'Telangana', 30, 'F', 'Content Creator', False),
    (477, 'Nabha Natesh', 'Sringeri', 'Karnataka', 28, 'F', 'Student', True),
    (478, 'Dimple Hayathi', 'Hyderabad', 'Telangana', 25, 'F', 'Student', True),
    (479, 'Meenakshi Chaudhary', 'Panchkula', 'Haryana', 27, 'F', 'Medical Professional', False),
    (480, 'Krithi Shetty', 'Mangaluru', 'Karnataka', 22, 'F', 'Student', True),
    (481, 'Sreeleela Detroit', 'Detroit', 'USA', 24, 'F', 'Medical Professional', True),
    (482, 'Ashika Ranganath', 'Tumkur', 'Karnataka', 27, 'F', 'Student', False),
    (483, 'Rachita Ram', 'Bengaluru', 'Karnataka', 31, 'F', 'Artist', True),
    (484, 'Radhika Pandit', 'Uttara Kannada', 'Karnataka', 40, 'F', 'Manager', False),
    (485, 'Hariprriya Chikka', 'Chikkaballapur', 'Karnataka', 34, 'F', 'Artist', True),
    (486, 'Pranitha Subhash', 'Bengaluru', 'Karnataka', 31, 'F', 'Business Owner', True),
    (487, 'Swathi Reddy', 'Vladivostok', 'Russia', 39, 'F', 'Manager', False),
    (488, 'Sri Divya', 'Hyderabad', 'Telangana', 31, 'F', 'Teacher', True),
    (489, 'Tejaswi Madivada', 'Hyderabad', 'Telangana', 33, 'F', 'Content Creator', True),
    (490, 'Hebah Patel', 'Mumbai', 'Maharashtra', 31, 'F', 'Student', False),
    (491, 'Nandita Swetha', 'Bengaluru', 'Karnataka', 34, 'F', 'Teacher', True),
    (492, 'Chandini Chowdary', 'Vizag', 'Andhra Pradesh', 31, 'F', 'Artist', False),
    (493, 'Ananya Nagalla', 'Suryapet', 'Telangana', 29, 'F', 'Software Engineer', True),
    (494, 'Eesha Rebba', 'Hyderabad', 'Telangana', 33, 'F', 'Software Engineer', True),
    (495, 'Shalini Pandey', 'Jabalpur', 'Madhya Pradesh', 30, 'F', 'Student', False),
    (496, 'Niveda Thomas', 'Chennai', 'Tamil Nadu', 28, 'F', 'Student', True),
    (497, 'Regina Cassandra', 'Chennai', 'Tamil Nadu', 35, 'F', 'Artist', False),
    (498, 'Pooja Ramachandran', 'Chennai', 'Tamil Nadu', 39, 'F', 'Content Creator', True),
    (499, 'Samantha Akkineni', 'Chennai', 'Tamil Nadu', 37, 'F', 'Artist', True),
    (500, 'Ileana DCruz', 'Mumbai', 'Maharashtra', 39, 'F', 'Artist', False)
]

# %%
customer = spark.createDataFrame(data= customers_data, schema= customers_schema)

customer.show()

# %%
purchases_schema = [
    'purchase_id', 'customer_id', 'bike_id', 'purchase_date', 
    'payment_method', 'insurance_opted', 'accessories_cost_inr'
]


purchases_data = [
    (1001, 14, 114, '2025-01-03', 'Net Banking', True, 4500),
    (1002, 287, 106, '2025-01-03', 'Credit Card', False, 0),
    (1003, 92, 101, '2025-01-04', 'Cash', True, 1200),
    (1004, 143, 119, '2025-01-06', 'Financed', True, 8500),
    (1005, 311, 105, '2025-01-06', 'Credit Card', True, 12000),
    (1006, 54, 110, '2025-01-09', 'UPI', False, 1500),
    (1007, 201, 103, '2025-01-11', 'Cash', True, 2100),
    (1008, 365, 118, '2025-01-11', 'Financed', True, 6400),
    (1009, 122, 108, '2025-01-12', 'UPI', False, 0),
    (1010, 8, 115, '2025-01-14', 'Credit Card', True, 4300),
    (1011, 184, 102, '2025-01-15', 'Financed', True, 3200),
    (1012, 299, 107, '2025-01-17', 'Net Banking', False, 1800),
    (1013, 47, 120, '2025-01-19', 'UPI', True, 2500),
    (1014, 340, 113, '2025-01-20', 'Cash', False, 0),
    (1015, 222, 104, '2025-01-22', 'Financed', True, 5100),
    (1016, 73, 111, '2025-01-23', 'UPI', True, 1100),
    (1017, 159, 116, '2025-01-25', 'Cash', False, 900),
    (1018, 264, 112, '2025-01-25', 'Net Banking', True, 2300),
    (1019, 11, 109, '2025-01-28', 'Credit Card', False, 0),
    (1020, 195, 117, '2025-01-30', 'UPI', True, 3800),
    (1021, 318, 101, '2025-02-01', 'Cash', True, 1500),
    (1022, 85, 106, '2025-02-01', 'UPI', False, 0),
    (1023, 137, 105, '2025-02-03', 'Financed', True, 14000),
    (1024, 250, 119, '2025-02-04', 'Credit Card', True, 9200),
    (1025, 41, 103, '2025-02-06', 'Net Banking', False, 1300),
    (1026, 305, 114, '2025-02-07', 'Cash', True, 2700),
    (1027, 166, 102, '2025-02-09', 'Financed', True, 4000),
    (1028, 98, 110, '2025-02-11', 'UPI', True, 3100),
    (1029, 213, 108, '2025-02-12', 'Cash', False, 0),
    (1030, 351, 118, '2025-02-14', 'Financed', True, 7800),
    (1031, 29, 113, '2025-02-15', 'UPI', True, 2100),
    (1032, 174, 104, '2025-02-17', 'Credit Card', False, 3400),
    (1033, 281, 115, '2025-02-19', 'Financed', True, 5000),
    (1034, 62, 111, '2025-02-20', 'Cash', False, 800),
    (1035, 125, 116, '2025-02-22', 'Net Banking', True, 1200),
    (1036, 243, 117, '2025-02-23', 'UPI', True, 4200),
    (1037, 333, 112, '2025-02-25', 'Credit Card', False, 0),
    (1038, 50, 120, '2025-02-26', 'UPI', True, 2200),
    (1039, 189, 109, '2025-02-28', 'Cash', True, 1900),
    (1040, 272, 101, '2025-03-01', 'Net Banking', False, 1100),
    (1041, 103, 106, '2025-03-02', 'UPI', True, 2500),
    (1042, 199, 105, '2025-03-04', 'Financed', True, 11000),
    (1043, 12, 119, '2025-03-05', 'Credit Card', True, 8800),
    (1044, 321, 103, '2025-03-07', 'Cash', False, 0),
    (1045, 148, 114, '2025-03-08', 'Net Banking', True, 3100),
    (1046, 235, 102, '2025-03-10', 'Financed', True, 4500),
    (1047, 77, 110, '2025-03-11', 'UPI', False, 1800),
    (1048, 360, 118, '2025-03-13', 'Financed', True, 9500),
    (1049, 161, 108, '2025-03-14', 'Cash', True, 1300),
    (1050, 290, 113, '2025-03-16', 'UPI', False, 0),
    (1051, 88, 104, '2025-03-17', 'Credit Card', True, 5200),
    (1052, 217, 115, '2025-03-19', 'Financed', True, 6000),
    (1053, 344, 111, '2025-03-20', 'Cash', False, 700),
    (1054, 43, 116, '2025-03-22', 'Net Banking', True, 2000),
    (1055, 131, 117, '2025-03-23', 'UPI', True, 3900),
    (1056, 255, 112, '2025-03-25', 'Credit Card', False, 1500),
    (1057, 309, 120, '2025-03-26', 'UPI', True, 2600),
    (1058, 182, 109, '2025-03-28', 'Cash', False, 0),
    (1059, 279, 101, '2025-03-29', 'UPI', True, 1400),
    (1060, 95, 106, '2025-03-31', 'Net Banking', True, 2200),
    (1061, 204, 105, '2025-04-01', 'Financed', True, 13500),
    (1062, 337, 119, '2025-04-02', 'Credit Card', False, 7100),
    (1063, 19, 103, '2025-04-04', 'Cash', True, 2400),
    (1064, 152, 114, '2025-04-05', 'UPI', True, 3300),
    (1065, 241, 102, '2025-04-07', 'Financed', False, 0),
    (1066, 68, 110, '2025-04-08', 'UPI', True, 2900),
    (1067, 355, 118, '2025-04-10', 'Financed', True, 8200),
    (1068, 114, 108, '2025-04-11', 'Cash', False, 600),
    (1069, 227, 113, '2025-04-13', 'Net Banking', True, 1800),
    (1070, 315, 104, '2025-04-14', 'Credit Card', True, 4900),
    (1071, 59, 115, '2025-04-16', 'Financed', False, 3800),
    (1072, 141, 111, '2025-04-17', 'Cash', True, 1100),
    (1073, 268, 116, '2025-04-19', 'UPI', True, 1600),
    (1074, 329, 117, '2025-04-20', 'Net Banking', False, 0),
    (1075, 25, 112, '2025-04-22', 'Credit Card', True, 2800),
    (1076, 139, 120, '2025-04-23', 'UPI', True, 3000),
    (1077, 249, 109, '2025-04-25', 'Cash', True, 2100),
    (1078, 362, 101, '2025-04-26', 'UPI', False, 900),
    (1079, 82, 106, '2025-04-28', 'Net Banking', True, 2400),
    (1080, 171, 105, '2025-04-29', 'Financed', True, 15000),
    (1081, 294, 119, '2025-05-01', 'Credit Card', True, 9500),
    (1082, 33, 103, '2025-05-02', 'Cash', False, 0),
    (1083, 119, 114, '2025-05-04', 'UPI', True, 3600),
    (1084, 231, 102, '2025-05-05', 'Financed', True, 4100),
    (1085, 349, 110, '2025-05-07', 'UPI', False, 1200),
    (1086, 52, 118, '2025-05-08', 'Financed', True, 11000),
    (1087, 163, 108, '2025-05-10', 'Cash', True, 1400),
    (1088, 252, 113, '2025-05-11', 'Net Banking', False, 0),
    (1089, 310, 104, '2025-05-13', 'Credit Card', True, 5600),
    (1090, 91, 115, '2025-05-14', 'Financed', True, 6200),
    (1091, 180, 111, '2025-05-16', 'Cash', True, 1300),
    (1092, 283, 116, '2025-05-17', 'UPI', False, 800),
    (1093, 369, 117, '2025-05-19', 'Net Banking', True, 4500),
    (1094, 4, 112, '2025-05-20', 'Credit Card', True, 3100),
    (1095, 128, 120, '2025-05-22', 'UPI', False, 2100),
    (1096, 219, 109, '2025-05-23', 'Cash', True, 2500),
    (1097, 302, 101, '2025-05-25', 'UPI', True, 1600),
    (1098, 65, 106, '2025-05-26', 'Net Banking', False, 0),
    (1099, 154, 105, '2025-05-28', 'Financed', True, 12500),
    (1100, 261, 119, '2025-05-29', 'Credit Card', True, 8900),
    (1101, 357, 103, '2025-05-31', 'Cash', True, 1900),
    (1102, 10, 114, '2025-06-01', 'UPI', False, 2800),
    (1103, 112, 102, '2025-06-03', 'Financed', True, 4300),
    (1104, 225, 110, '2025-06-04', 'UPI', True, 3500),
    (1105, 330, 118, '2025-06-06', 'Financed', True, 10500),
    (1106, 46, 108, '2025-06-07', 'Cash', False, 0),
    (1107, 135, 113, '2025-06-09', 'Net Banking', True, 2300),
    (1108, 246, 104, '2025-06-10', 'Credit Card', True, 5800),
    (1109, 342, 115, '2025-06-12', 'Financed', False, 4100),
    (1110, 71, 111, '2025-06-13', 'Cash', True, 1250),
    (1111, 168, 116, '2025-06-15', 'UPI', True, 1750),
    (1112, 275, 117, '2025-06-16', 'Net Banking', False, 3600),
    (1113, 366, 112, '2025-06-18', 'Credit Card', True, 2900),
    (1114, 16, 120, '2025-06-19', 'UPI', True, 3200),
    (1115, 121, 109, '2025-06-21', 'Cash', False, 0),
    (1116, 209, 101, '2025-06-22', 'UPI', True, 1350),
    (1117, 297, 106, '2025-06-24', 'Net Banking', True, 2600),
    (1118, 55, 105, '2025-06-25', 'Financed', True, 14200),
    (1119, 146, 119, '2025-06-27', 'Credit Card', False, 7500),
    (1120, 238, 103, '2025-06-28', 'Cash', True, 2200),
    (1121, 326, 114, '2025-06-30', 'UPI', True, 3400),
    (1122, 23, 102, '2025-07-01', 'Financed', True, 4800),
    (1123, 117, 110, '2025-07-03', 'UPI', False, 1600),
    (1124, 212, 118, '2025-07-04', 'Financed', True, 9000),
    (1125, 307, 108, '2025-07-06', 'Cash', True, 1150),
    (1126, 39, 113, '2025-07-07', 'Net Banking', False, 0),
    (1127, 150, 104, '2025-07-09', 'Credit Card', True, 6100),
    (1128, 258, 115, '2025-07-10', 'Financed', True, 5400),
    (1129, 353, 111, '2025-07-12', 'Cash', False, 950),
    (1130, 80, 116, '2025-07-13', 'UPI', True, 1900),
    (1131, 177, 117, '2025-07-15', 'Net Banking', True, 4100),
    (1132, 285, 112, '2025-07-16', 'Credit Card', False, 2100),
    (1133, 372, 120, '2025-07-18', 'UPI', True, 2850),
    (1134, 15, 109, '2025-07-19', 'Cash', True, 2300),
    (1135, 104, 101, '2025-07-21', 'UPI', False, 1000),
    (1136, 192, 106, '2025-07-22', 'Net Banking', True, 2450),
    (1137, 289, 105, '2025-07-24', 'Financed', True, 11800),
    (1138, 34, 119, '2025-07-25', 'Credit Card', True, 9300),
    (1139, 126, 103, '2025-07-27', 'Cash', False, 0),
    (1140, 245, 114, '2025-07-28', 'UPI', True, 3150),
    (1141, 335, 102, '2025-07-30', 'Financed', True, 4600),
    (1142, 60, 110, '2025-08-01', 'UPI', True, 3350),
    (1143, 145, 118, '2025-08-02', 'Financed', False, 8700),
    (1144, 263, 108, '2025-08-04', 'Cash', True, 1250),
    (1145, 350, 113, '2025-08-05', 'Net Banking', True, 2050),
    (1146, 5, 104, '2025-08-07', 'Credit Card', False, 4800),
    (1147, 96, 115, '2025-08-08', 'Financed', True, 6700),
    (1148, 185, 111, '2025-08-10', 'Cash', True, 1400),
    (1149, 273, 116, '2025-08-11', 'UPI', False, 0),
    (1150, 359, 117, '2025-08-13', 'Net Banking', True, 4400),
    (1151, 18, 112, '2025-08-14', 'Credit Card', True, 3250),
    (1152, 109, 120, '2025-08-16', 'UPI', True, 2700),
    (1153, 224, 109, '2025-08-17', 'Cash', False, 1800),
    (1154, 301, 101, '2025-08-19', 'UPI', True, 1550),
    (1155, 49, 106, '2025-08-20', 'Net Banking', True, 2100),
    (1156, 138, 105, '2025-08-22', 'Financed', True, 13000),
    (1157, 251, 119, '2025-08-23', 'Credit Card', False, 8100),
    (1158, 345, 103, '2025-08-25', 'Cash', True, 2350),
    (1159, 27, 114, '2025-08-26', 'UPI', True, 3650),
    (1160, 115, 102, '2025-08-28', 'Financed', False, 3900),
    (1161, 233, 110, '2025-08-29', 'UPI', True, 2950),
    (1162, 314, 118, '2025-08-31', 'Financed', True, 10000),
    (1163, 63, 108, '2025-09-01', 'Cash', False, 0),
    (1164, 157, 113, '2025-09-02', 'Net Banking', True, 2400),
    (1165, 240, 104, '2025-09-04', 'Credit Card', True, 5400),
    (1166, 327, 115, '2025-09-05', 'Financed', True, 5900),
    (1167, 72, 111, '2025-09-07', 'Cash', False, 1100),
    (1168, 164, 116, '2025-09-08', 'UPI', True, 1650),
    (1169, 269, 117, '2025-09-10', 'Net Banking', True, 4250),
    (1170, 363, 112, '2025-09-11', 'Credit Card', False, 2600),
    (1171, 9, 120, '2025-09-13', 'UPI', True, 3100),
    (1172, 101, 109, '2025-09-14', 'Cash', True, 2200),
    (1173, 196, 101, '2025-09-16', 'UPI', False, 850),
    (1174, 282, 106, '2025-09-17', 'Net Banking', True, 2300),
    (1175, 51, 105, '2025-09-19', 'Financed', True, 12200),
    (1176, 142, 119, '2025-09-20', 'Credit Card', True, 9400),
    (1177, 229, 103, '2025-09-22', 'Cash', False, 0),
    (1178, 322, 114, '2025-09-23', 'UPI', True, 3500),
    (1179, 31, 102, '2025-09-25', 'Financed', True, 4400),
    (1180, 120, 110, '2025-09-26', 'UPI', False, 1400),
    (1181, 215, 118, '2025-09-28', 'Financed', True, 11500),
    (1182, 304, 108, '2025-09-29', 'Cash', True, 1300),
    (1183, 42, 113, '2025-10-01', 'Net Banking', True, 1950),
    (1184, 133, 104, '2025-10-02', 'Credit Card', False, 3800),
    (1185, 256, 115, '2025-10-04', 'Financed', True, 6100),
    (1186, 352, 111, '2025-10-05', 'Cash', True, 1200),
    (1187, 81, 116, '2025-10-07', 'UPI', False, 0),
    (1188, 172, 117, '2025-10-08', 'Net Banking', True, 4000),
    (1189, 291, 112, '2025-10-10', 'Credit Card', True, 3000),
    (1190, 370, 120, '2025-10-11', 'UPI', True, 2550),
    (1191, 13, 109, '2025-10-13', 'Cash', False, 1500),
    (1192, 105, 101, '2025-10-14', 'UPI', True, 1450),
    (1193, 187, 106, '2025-10-16', 'Net Banking', True, 2250),
    (1194, 276, 105, '2025-10-17', 'Financed', True, 14800),
    (1195, 35, 119, '2025-10-19', 'Credit Card', False, 7200),
    (1196, 130, 103, '2025-10-20', 'Cash', True, 2150),
    (1197, 244, 114, '2025-10-22', 'UPI', True, 3200),
    (1198, 334, 102, '2025-10-23', 'Financed', True, 4200),
    (1199, 58, 110, '2025-10-25', 'UPI', False, 2000),
    (1200, 149, 118, '2025-10-26', 'Financed', True, 9200),
    (1201, 260, 108, '2025-10-28', 'Cash', True, 1100),
    (1202, 347, 113, '2025-10-29', 'Net Banking', False, 0),
    (1203, 6, 104, '2025-10-31', 'Credit Card', True, 5300),
    (1204, 94, 115, '2025-11-01', 'Financed', True, 5500),
    (1205, 181, 111, '2025-11-03', 'Cash', False, 850),
    (1206, 271, 116, '2025-11-04', 'UPI', True, 1800),
    (1207, 361, 117, '2025-11-06', 'Net Banking', True, 4600),
    (1208, 17, 112, '2025-11-07', 'Credit Card', False, 1900),
    (1209, 110, 120, '2025-11-09', 'UPI', True, 2900),
    (1210, 221, 109, '2025-11-10', 'Cash', True, 2600),
    (1211, 303, 101, '2025-11-12', 'UPI', True, 1300),
    (1212, 48, 106, '2025-11-13', 'Net Banking', False, 0),
    (1213, 140, 105, '2025-11-15', 'Financed', True, 13200),
    (1214, 253, 119, '2025-11-16', 'Credit Card', True, 9100),
    (1215, 346, 103, '2025-11-18', 'Cash', True, 2000),
    (1216, 28, 114, '2025-11-19', 'UPI', False, 2500),
    (1217, 113, 102, '2025-11-21', 'Financed', True, 4700),
    (1218, 232, 110, '2025-11-22', 'UPI', True, 3400),
    (1219, 313, 118, '2025-11-24', 'Financed', True, 10800),
    (1220, 64, 108, '2025-11-25', 'Cash', False, 0),
    (1221, 156, 113, '2025-11-27', 'Net Banking', True, 2200),
    (1222, 239, 104, '2025-11-28', 'Credit Card', True, 5700),
    (1223, 328, 115, '2025-11-30', 'Financed', False, 3600),
    (1224, 73, 111, '2025-12-01', 'Cash', True, 1150),
    (1225, 165, 116, '2025-12-03', 'UPI', True, 1700),
    (1226, 270, 117, '2025-12-04', 'Net Banking', False, 4100),
    (1227, 364, 112, '2025-12-06', 'Credit Card', True, 2750),
    (1228, 7, 120, '2025-12-07', 'UPI', True, 3050),
    (1229, 102, 109, '2025-12-09', 'Cash', False, 0),
    (1230, 197, 101, '2025-12-10', 'UPI', True, 1500),
    (1231, 281, 106, '2025-12-12', 'Net Banking', True, 2400),
    (1232, 52, 105, '2025-12-13', 'Financed', True, 15500),
    (1233, 143, 119, '2025-12-15', 'Credit Card', True, 8600),
    (1234, 228, 103, '2025-12-16', 'Cash', False, 1200),
    (1235, 323, 114, '2025-12-18', 'UPI', True, 3300),
    (1236, 30, 102, '2025-12-19', 'Financed', True, 4250),
    (1237, 121, 110, '2025-12-21', 'UPI', False, 1900),
    (1238, 214, 118, '2025-12-22', 'Financed', True, 9900),
    (1239, 305, 108, '2025-12-24', 'Cash', True, 1400),
    (1240, 41, 113, '2025-12-25', 'Net Banking', False, 0),
    (1241, 134, 104, '2025-12-27', 'Credit Card', True, 6000),
    (1242, 257, 115, '2025-12-28', 'Financed', True, 5200),
    (1243, 351, 111, '2025-12-30', 'Cash', True, 1000),
    (1244, 82, 116, '2025-12-31', 'UPI', False, 1350),
    (1245, 173, 117, '2026-01-02', 'Net Banking', True, 4300),
    (1246, 292, 112, '2026-01-03', 'Credit Card', True, 3100),
    (1247, 371, 120, '2026-01-05', 'UPI', True, 2750),
    (1248, 14, 109, '2026-01-06', 'Cash', False, 0),
    (1249, 106, 101, '2026-01-08', 'UPI', True, 1600),
    (1250, 186, 106, '2026-01-09', 'Net Banking', True, 2150),
    (1251, 277, 105, '2026-01-11', 'Financed', True, 14000),
    (1252, 36, 119, '2026-01-12', 'Credit Card', False, 7900),
    (1253, 129, 103, '2026-01-14', 'Cash', True, 2500),
    (1254, 243, 114, '2026-01-15', 'UPI', True, 3400),
    (1255, 333, 102, '2026-01-17', 'Financed', True, 4500),
    (1256, 57, 110, '2026-01-18', 'UPI', False, 1100),
    (1257, 148, 118, '2026-01-20', 'Financed', True, 11200),
    (1258, 261, 108, '2026-01-21', 'Cash', True, 1200),
    (1259, 348, 113, '2026-01-23', 'Net Banking', False, 0),
    (1260, 7, 104, '2026-01-24', 'Credit Card', True, 4900),
    (1261, 93, 115, '2026-01-26', 'Financed', True, 6300),
    (1262, 182, 111, '2026-01-27', 'Cash', False, 750),
    (1263, 272, 116, '2026-01-29', 'UPI', True, 1850),
    (1264, 362, 117, '2026-01-30', 'Net Banking', True, 4700),
    (1265, 19, 112, '2026-02-01', 'Credit Card', False, 2200),
    (1266, 111, 120, '2026-02-02', 'UPI', True, 3200),
    (1267, 222, 109, '2026-02-04', 'Cash', True, 2400),
    (1268, 304, 101, '2026-02-05', 'UPI', True, 1250),
    (1269, 47, 106, '2026-02-07', 'Net Banking', False, 0),
    (1270, 141, 105, '2026-02-08', 'Financed', True, 12800),
    (1271, 254, 119, '2026-02-10', 'Credit Card', True, 8700),
    (1272, 345, 103, '2026-02-11', 'Cash', True, 1800),
    (1273, 29, 114, '2026-02-13', 'UPI', False, 2900),
    (1274, 114, 102, '2026-02-14', 'Financed', True, 4100),
    (1275, 231, 110, '2026-02-16', 'UPI', True, 3600),
    (1276, 312, 118, '2026-02-17', 'Financed', True, 10300),
    (1277, 65, 108, '2026-02-19', 'Cash', False, 650),
    (1278, 155, 113, '2026-02-20', 'Net Banking', True, 2100),
    (1279, 238, 104, '2026-02-22', 'Credit Card', True, 5500),
    (1280, 329, 115, '2026-02-23', 'Financed', False, 4400),
    (1281, 74, 111, '2026-02-25', 'Cash', True, 1300),
    (1282, 166, 116, '2026-02-26', 'UPI', True, 1600),
    (1283, 271, 117, '2026-02-28', 'Net Banking', False, 3950),
    (1284, 365, 112, '2026-03-01', 'Credit Card', True, 2800),
    (1285, 8, 120, '2026-03-02', 'UPI', True, 2950),
    (1286, 103, 109, '2026-03-04', 'Cash', False, 0),
    (1287, 198, 101, '2026-03-05', 'UPI', True, 1400),
    (1288, 280, 106, '2026-03-07', 'Net Banking', True, 2500),
    (1289, 53, 105, '2026-03-08', 'Financed', True, 16000),
    (1290, 144, 119, '2026-03-10', 'Credit Card', True, 9200),
    (1291, 227, 103, '2026-03-11', 'Cash', False, 1100),
    (1292, 324, 114, '2026-03-13', 'UPI', True, 3450),
    (1293, 31, 102, '2026-03-14', 'Financed', True, 4350),
    (1294, 122, 110, '2026-03-16', 'UPI', False, 2100),
    (1295, 213, 118, '2026-03-17', 'Financed', True, 9700),
    (1296, 306, 108, '2026-03-19', 'Cash', True, 1500),
    (1297, 40, 113, '2026-03-20', 'Net Banking', False, 0),
    (1298, 135, 104, '2026-03-22', 'Credit Card', True, 6200),
    (1299, 258, 115, '2026-03-23', 'Financed', True, 5100),
    (1300, 350, 111, '2026-03-25', 'Cash', True, 1050),
    (1301, 83, 116, '2026-03-26', 'UPI', False, 1400),
    (1302, 174, 117, '2026-03-28', 'Net Banking', True, 4200),
    (1303, 290, 112, '2026-03-29', 'Credit Card', True, 3200),
    (1304, 372, 120, '2026-03-31', 'UPI', True, 2600),
    (1305, 15, 109, '2026-04-01', 'Cash', False, 0),
    (1306, 107, 101, '2026-04-02', 'UPI', True, 1650),
    (1307, 185, 106, '2026-04-04', 'Net Banking', True, 2200),
    (1308, 278, 105, '2026-04-05', 'Financed', True, 14500),
    (1309, 37, 119, '2026-04-07', 'Credit Card', False, 7600),
    (1310, 128, 103, '2026-04-08', 'Cash', True, 2400),
    (1311, 242, 114, '2026-04-10', 'UPI', True, 3350),
    (1312, 332, 102, '2026-04-11', 'Financed', True, 4600),
    (1313, 56, 110, '2026-04-13', 'UPI', False, 1250),
    (1314, 147, 118, '2026-04-14', 'Financed', True, 11000),
    (1315, 262, 108, '2026-04-16', 'Cash', True, 1350),
    (1316, 349, 113, '2026-04-17', 'Net Banking', False, 0),
    (1317, 8, 104, '2026-04-19', 'Credit Card', True, 5100),
    (1318, 92, 115, '2026-04-20', 'Financed', True, 6400),
    (1319, 183, 111, '2026-04-22', 'Cash', False, 800),
    (1320, 273, 116, '2026-04-23', 'UPI', True, 1900),
    (1321, 363, 117, '2026-04-25', 'Net Banking', True, 4800),
    (1322, 20, 112, '2026-04-26', 'Credit Card', False, 2100),
    (1323, 112, 120, '2026-04-28', 'UPI', True, 3150),
    (1324, 223, 109, '2026-04-29', 'Cash', True, 2300),
    (1325, 305, 101, '2026-05-01', 'UPI', True, 1300),
    (1326, 46, 106, '2026-05-02', 'Net Banking', False, 0),
    (1327, 142, 105, '2026-05-04', 'Financed', True, 13100),
    (1328, 255, 119, '2026-05-05', 'Credit Card', True, 8900),
    (1329, 344, 103, '2026-05-07', 'Cash', True, 1750),
    (1330, 30, 114, '2026-05-08', 'UPI', False, 2850),
    (1331, 115, 102, '2026-05-10', 'Financed', True, 4200),
    (1332, 232, 110, '2026-05-11', 'UPI', True, 3550),
    (1333, 311, 118, '2026-05-13', 'Financed', True, 10500),
    (1334, 66, 108, '2026-05-14', 'Cash', False, 700),
    (1335, 154, 113, '2026-05-16', 'Net Banking', True, 2250),
    (1336, 237, 104, '2026-05-17', 'Credit Card', True, 5400),
    (1337, 330, 115, '2026-05-19', 'Financed', False, 4300),
    (1338, 75, 111, '2026-05-20', 'Cash', True, 1200),
    (1339, 167, 116, '2026-05-22', 'UPI', True, 1650),
    (1340, 272, 117, '2026-05-23', 'Net Banking', False, 3800),
    (1341, 366, 112, '2026-05-25', 'Credit Card', True, 2700),
    (1342, 9, 120, '2026-05-26', 'UPI', True, 2800),
    (1343, 104, 109, '2026-05-28', 'Cash', False, 0),
    (1344, 199, 101, '2026-05-29', 'UPI', True, 1450),
    (1345, 279, 106, '2026-05-31', 'Net Banking', True, 2600),
    (1346, 54, 105, '2026-06-01', 'Financed', True, 15800),
    (1347, 145, 119, '2026-06-02', 'Credit Card', True, 9100),
    (1348, 226, 103, '2026-06-04', 'Cash', False, 1000),
    (1349, 325, 114, '2026-06-05', 'UPI', True, 3500),
    (1350, 32, 102, '2026-06-07', 'Financed', True, 4400)
]

# %%
purchase = spark.createDataFrame(data= purchases_data, schema= purchases_schema)

purchase.show()

# %% [markdown]
# ### Joins

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# #### Left Join

# %%
customer.join(purchase,on=customer['customer_id'] == purchase['customer_id'],how='left')\
    .sort(purchase['accessories_cost_inr'].desc()).display()

# %% [markdown]
# #### Right Join

# %%
purchase.join(bike,on= purchase['bike_id'] == bike['bike_id'],how='right').display()

# %% [markdown]
# #### Inner Join

# %%
customer.join(purchase,on=customer['customer_id'] == purchase['customer_id'],how='inner')\
        .display()

# %% [markdown]
# #### Outer Join

# %%
customer.join(purchase,on=customer['customer_id'] == purchase['customer_id'],how='outer')\
    .display()

# %% [markdown]
# #### Left Semi Join

# %%
bike.join(purchase,on= purchase['bike_id'] == bike['bike_id'],how='left_semi').display()

# %%
customer.join(purchase,on= purchase['customer_id'] == customer['customer_id'],how='left_semi')\
    .sort('customer_name').display()

# %% [markdown]
# #### Left Anti Join

# %%
customer.join(purchase,on= purchase['customer_id'] == customer['customer_id'],how='left_anti')\
    .sort('customer_name').display()

# %%
print(customer.columns)
print(purchase.columns)
print(bike.columns)

# %% [markdown]
# ### Window Fuctions

# %%
df_1 = customer.join(purchase, on='customer_id', how= 'left')
df = df_1.join(bike, on='bike_id',how='left')
df.display()
